# %%
github

databricks free edition

types on compute

unity catalog

git hub integration
dab's

# %%
showing on pull request on databricks

# %%
done with git intgreation

# %%
databricks --help

# %%
databricks clusters -h


databricks clusters list



databricks job -h

databricks jobs list
